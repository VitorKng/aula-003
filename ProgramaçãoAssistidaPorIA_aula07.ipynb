# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorKng/engenharia-de-prompt-fundamentos/blob/main/Programa%C3%A7%C3%A3oAssistidaPorIA_aula07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 07 _ Miniprojeto
#
# ####Professor: Kadidja Valéria
# ####Aluno: Vitor Oliveira F. Alves
# ####Diciplina: Engenharia de Prompt e Aplicações em IA

# %%
#soma de lista
numeros = [1, 2, 3, 2, 1]
soma = 0
i = 0
while i < len(numeros):
  soma = soma + numeros[i]
  i = i + 1
print(soma)
# Out:
# 9

# %%
#soma de lista
numeros = [1, 2, 3, 2, 1]
soma = sum(numeros)
print(soma)
# Out:
# 9

# %%
#Numero primo
def eh_primo(n):
  if n < 2:  # Numeros menores que 2 não são primos
    return False
  if n == 2: # 2 é o único número primo par
    return True
  if n % 2 == 0: # Outros números pares não são primos
    return False
  # Verifica divisores ímpares a partir de 3 até a raiz quadrada de n
  for i in range(3, int(n**0.5) + 1, 2):
    if n % i == 0:
      return False
  return True

# %%
import math

# %%
# Testando a função eh_primo
print(f"O número 7 é primo? {eh_primo(7)}")
print(f"O número 10 é primo? {eh_primo(10)}")
print(f"O número 2 é primo? {eh_primo(2)}")
print(f"O número 1 é primo? {eh_primo(1)}")
print(f"O número 0 é primo? {eh_primo(0)}")
# Out:
# O número 7 é primo? True
# O número 10 é primo? False
# O número 2 é primo? True
# O número 1 é primo? True
# O número 0 é primo? True

# %%
#Inversão de string
def inverte_texto(Vitor):
  invertido = ""
  for letra in Vitor:
    invertido = letra+invertido
  return invertido

# %%
print(f"'Vitor' invertido é: {inverte_texto('Vitor')}")
print(f"'Python' invertido é: {inverte_texto('Python')}")
print(f"'Olá Mundo' invertido é: {inverte_texto('Olá Mundo')}")
print(f"'a' invertido é: {inverte_texto('a')}")
print(f"'' (string vazia) invertido é: {inverte_texto('')}")
# Out:
# 'Vitor' invertido é: rotiV
# 'Python' invertido é: nohtyP
# 'Olá Mundo' invertido é: odnuM álO
# 'a' invertido é: a
# '' (string vazia) invertido é:
